# %%
import pandas as pd
import os
from keplergl import KeplerGl

map1 = KeplerGl(height =500)
map1
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(height=500)

# %%
with open('Miami_15minslowwalk.json', 'r') as f:
    geojson = f.read()
map1.add_data(data=geojson, name='geojson')

# %%
data_path = ['/Users/laragarcia/Kepler_Test']
filepath = os.sep.join(data_path + ['fl_census_data_final.csv'])
print(filepath)

df = pd.read_csv(filepath)
# Out:
# /Users/laragarcia/Kepler_Test/fl_census_data_final.csv

# %%
df.head()
# Out:
#    Estimate!!SEX AND AGE!!Total population  \
# 0                                     2439
# 1                                     3207
# 2                                     2588
# 3                                     1162
# 4                                     4226
#
#   Margin of Error!!SEX AND AGE!!Total population  \
# 0                                            494
# 1                                            593
# 2                                            430
# 3                                            360
# 4                                            586
#
#    Percent!!SEX AND AGE!!Total population  \
# 0                                    2439
# 1                                    3207
# 2                                    2588
# 3                                    1162
# 4                                    4226
#
#   Percent Margin of Error!!SEX AND AGE!!Total population  \
# 0                                                (X)
# ...

# %%
import geopandas as gpd

gdf = gpd.read_file('fl_census_tract.json') # geojson file
pdf = pd.read_csv('fl_census_data_final.csv') # CSV file
pdf['GEOID'] = pdf['GEOID'].astype(str)

joined_gdf = gdf.merge(pdf, on='GEOID', how = 'left')
joined_gdf.to_file('fl_census_data_map.geojson', driver = 'GeoJSON')

# %%
with open('fl_census_data_map.geojson', 'r') as f:
    geojson = f.read()
map1.add_data(data=geojson, name='geojson2')

# %%
map1.save_to_html(file_name='Miami_map1.html')
# Out:
# Map saved to Miami_map1.html!
